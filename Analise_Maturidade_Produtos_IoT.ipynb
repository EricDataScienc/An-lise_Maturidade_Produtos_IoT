# %% [markdown]
# <a href="https://colab.research.google.com/github/EricDataScienc/An-lise_Maturidade_Produtos_IoT/blob/main/Analise_Maturidade_Produtos_IoT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparação do Ambiente

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Carregar o dataset

# %%
df = pd.read_csv('/content/tech_score_data.csv')

df.head()
# Out:
#    id_startup   nome_startup        setor   status data_avaliacao  \
# 0           1      AlphaTech     Agri-IoT    Ativa     2025-01-10
# 1           2  BetaSolutions    Water-Ops    Ativa     2025-01-11
# 2           3   GammaSystems    SmartCity  Inativa     2024-11-05
# 3           4   DeltaDevices  Enviro-Tech    Ativa     2025-01-12
# 4           5  EpsilonEnergy   Power-Grid    Ativa     2025-01-08
#
#    1.1_precisao_basica  1.2_calibracao  1.3_estabilidade_leitura  \
# 0                    4               5                         4
# 1                    3               4                         3
# 2                    2               3                         2
# 3                    5               5                         4
# 4                    4               4                         4
#
#    1.4_latencia_sinal  1.5_relacao_sinal_ruido  ...  7.1_perda_pacotes  \
# 0                   5                        5  ...                  5
# 1                   4                        4  ...                  4
# 2                   3                        2  ...                  2
# 3                   5                        5  ...                  5
# 4                   5                        5  ...                  5
#
#    7.2_latencia_nuvem  7.3_integridade_backup  7.4_resiliencia_api  \
# 0                   4                       5                    5
# 1                   3                       4                    4
# 2                   2                       3                    3
# 3                   5                       5                    5
# 4                   4                       4                    5
#
#    7.5_seguranca_cripto  8.1_risco_supply_chain  8.2_frequencia_manutencao  \
# 0                     3                       3                          5
# 1                     2                       2                          4
# 2                     1                       1                          3
# 3                     4                       4                          5
# 4                     3                       3                          5
#
#    8.3_indice_reparabilidade  8.4_tempo_montagem  8.5_ciclo_vida_material
# 0                          5                   4                        3
# 1                          4                   3                        2
# 2                          3                   2                        1
# 3                          5                   4                        3
# 4                          4                   4                        3
#
# [5 rows x 46 columns]

# %% [markdown]
# # Entendimento dos Dados

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_startup                 45 non-null     int64
#  1   nome_startup               45 non-null     object
#  2   setor                      45 non-null     object
#  3   status                     45 non-null     object
#  4   data_avaliacao             45 non-null     object
#  5   1.1_precisao_basica        45 non-null     int64
#  6   1.2_calibracao             45 non-null     int64
#  7   1.3_estabilidade_leitura   45 non-null     int64
#  8   1.4_latencia_sinal         45 non-null     int64
#  9   1.5_relacao_sinal_ruido    45 non-null     int64
#  10  1.6_repetibilidade         45 non-null     int64
#  11  2.1_custo_bom              45 non-null     int64
#  12  2.2_custo_opex             45 non-null     int64
#  13  2.3_tempo_deploy           45 non-null     int64
#  14  2.4_escalabilidade_fabril  45 non-null     int64
#  15  2.5_competitividade_preco  45 non-null     int64
#  16  2.6_mvp_funcional          45 non-null     int64
#  17  3.1_mtbf_teorico           45 non-null     int64
#  18  3.2_tratamento_erros       45 non-null     int64
#  19  3.3_estabilidade_firmware  45 non-null     int64
#  20  3.4_tempo_recuperacao      45 non-null     int64
#  21  3.5_stress_test            45 non-null     int64
#  22  4.1_tempo_instalacao       45 non-null     int64
#  23  4.2_facilidade_config      45 non-null     int64
#  24  4.3_clareza_dashboard      45 non-null     int64
#  25  4.4_feedback_usuario       45 non-null     int64
#  26  5.1_autonomia_bateria      45 non-null     int64
#  27  5.2_eficiencia_carga       45 non-null     int64
#  28  5.3_consumo_standby        45 non-null     int64
#  29  5.4_dimensionamento_fonte  45 non-null     int64
#  30  6.1_protecao_ip_agua       45 non-null     int64
#  31  6.2_resistencia_termica    45 non-null     int64
#  32  6.3_integridade_mecanica   45 non-null     int64
#  33  6.4_resistencia_impacto    45 non-null     int64
#  34  6.5_durabilidade_conector  45 non-null     int64
#  35  6.6_qualidade_carcaca      45 non-null     int64
#  36  7.1_perda_pacotes          45 non-null     int64
#  37  7.2_latencia_nuvem         45 non-null     int64
#  38  7.3_integridade_backup     45 non-null     int64
#  39  7.4_resiliencia_api        45 non-null     int64
#  40  7.5_seguranca_cripto       45 non-null     int64
#  41  8.1_risco_supply_chain     45 non-null     int64
#  42  8.2_frequencia_manutencao  45 non-null     int64
#  43  8.3_indice_reparabilidade  45 non-null     int64
#  44  8.4_tempo_montagem         45 non-null     int64
#  45  8.5_ciclo_vida_material    45 non-null     int64
# dtypes: int64(42), object(4)
# memory usage: 16.3+ KB
#        id_startup  1.1_precisao_basica  1.2_calibracao  \
# count   45.000000            45.000000       45.000000
# mean    23.000000             3.355556        3.777778
# std     13.133926             1.246004        1.063632
# min      1.000000             1.000000        2.000000
# 25%     12.000000             3.000000        3.000000
# 50%     23.000000             4.000000        4.000000
# 75%     34.000000             4.000000        5.000000
# max     45.000000             5.000000        5.000000
#
#        1.3_estabilidade_leitura  1.4_latencia_sinal  1.5_relacao_sinal_ruido  \
# count                 45.000000           45.000000                45.000000
# mean                   3.333333            3.933333                 3.866667
# std                    1.261312            1.095445                 1.324593
# min                    1.000000            2.000000                 1.000000
# 25%                    2.000000            3.000000                 3.000000
# 50%                    4.000000            4.000000                 4.000000
# 75%                    4.000000            5.000000                 5.000000
# max                    5.000000            5.000000                 5.000000
#
#        1.6_repetibilidade  2.1_custo_bom  2.2_custo_opex  2.3_tempo_deploy  \
# count           45.000000      45.000000       45.000000         45.000000
# mean             3.444444       3.333333        3.622222          3.044444
# std              1.235011       1.087115        1.386442          0.796457
# min              1.000000       1.000000        1.000000          2.000000
# 25%              2.000000       2.000000        3.000000          2.000000
# 50%              4.000000       4.000000        4.000000          3.000000
# 75%              4.000000       4.000000        5.000000          4.000000
# max              5.000000       5.000000        5.000000          5.000000
#
#        ...  7.1_perda_pacotes  7.2_latencia_nuvem  7.3_integridade_backup  \
# count  ...          45.000000           45.000000               45.000000
# mean   ...           3.866667            3.444444                3.800000
# std    ...           1.324593            1.178511                1.013545
# min    ...           1.000000            1.000000                2.000000
# 25%    ...           3.000000            2.000000                3.000000
# 50%    ...           4.000000            4.000000                4.000000
# 75%    ...           5.000000            4.000000                5.000000
# max    ...           5.000000            5.000000                5.000000
#
#        7.4_resiliencia_api  7.5_seguranca_cripto  8.1_risco_supply_chain  \
# count            45.000000             45.000000               45.000000
# mean              3.888889              2.488889                2.533333
# std               1.070731              1.079188                1.035725
# min               2.000000              1.000000                1.000000
# 25%               3.000000              2.000000                2.000000
# 50%               4.000000              3.000000                3.000000
# 75%               5.000000              3.000000                3.000000
# max               5.000000              4.000000                4.000000
#
#        8.2_frequencia_manutencao  8.3_indice_reparabilidade  \
# count                  45.000000                  45.000000
# mean                    3.888889                   3.755556
# std                     1.070731                   0.980620
# min                     2.000000                   2.000000
# 25%                     3.000000                   3.000000
# 50%                     4.000000                   4.000000
# 75%                     5.000000                   4.000000
# max                     5.000000                   5.000000
#
#        8.4_tempo_montagem  8.5_ciclo_vida_material
# count           45.000000                45.000000
# mean             3.177778                 2.511111
# std              1.093137                 0.968181
# min              1.000000                 1.000000
# 25%              2.000000                 2.000000
# 50%              4.000000                 3.000000
# 75%              4.000000                 3.000000
# max              5.000000                 4.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# # Separar Startups Ativas e Inativas

# %%
df_ativas = df[df['status'] == 'Ativa'].copy()
df_inativas = df[df['status'] == 'Inativa'].copy()

print('Ativas:', df_ativas.shape)
print('Inativas:', df_inativas.shape)
# Out:
# Ativas: (33, 46)
# Inativas: (12, 46)

# %% [markdown]
# # Criar o Score_Global

# %%
colunas_notas = [col for col in df.columns if col[0].isdigit()]

# %% [markdown]
# Calcular média geral

# %%
df_ativas['Score_Global'] = df_ativas[colunas_notas].mean(axis=1)
df_inativas['Score_Global'] = df_inativas[colunas_notas].mean(axis=1)

df_ativas[['id_startup', 'nome_startup', 'Score_Global']].head()
# Out:
#    id_startup   nome_startup  Score_Global
# 0           1      AlphaTech      4.268293
# 1           2  BetaSolutions      3.365854
# 3           4   DeltaDevices      4.634146
# 4           5  EpsilonEnergy      4.268293
# 6           7        EtaFlow      3.585366

# %% [markdown]
# # Visão Macro por Dimensão (Grupos)

# %%
grupos = {
    'Performance': '1.',
    'Viabilidade': '2.',
    'Confiabilidade': '3.',
    'Usabilidade': '4.',
    'Energia': '5.',
    'Fisico': '6.',
    'Conectividade': '7.',
    'Ciclo_de_Vida': '8.'
}

# %% [markdown]
# Calcular médias por grupo

# %%
for nome, prefixo in grupos.items():
    cols = [c for c in colunas_notas if c.startswith(prefixo)]
    df_ativas[nome] = df_ativas[cols].mean(axis=1)

df_ativas[list(grupos.keys())].head()
# Out:
#    Performance  Viabilidade  Confiabilidade  Usabilidade  Energia    Fisico  \
# 0     4.500000     3.666667             4.6         4.25     3.75  4.833333
# 1     3.500000     3.000000             3.6         3.25     2.75  4.166667
# 3     4.833333     4.166667             4.8         4.75     4.50  5.000000
# 4     4.333333     3.833333             4.4         4.25     4.50  4.833333
# 6     3.833333     3.166667             3.8         3.50     3.00  4.333333
#
#    Conectividade  Ciclo_de_Vida
# 0            4.4            4.0
# 1            3.4            3.0
# 3            4.8            4.2
# 4            4.2            3.8
# 6            3.8            3.0

# %% [markdown]
# # Startup com Melhor Score_Global

# %%
top_startup = df_ativas.sort_values('Score_Global', ascending=False).iloc[0]
top_startup[['id_startup', 'nome_startup', 'Score_Global']]
# Out:
# id_startup             28
# nome_startup    DaletSafe
# Score_Global     4.878049
# Name: 27, dtype: object

# %% [markdown]
# # Gráfico de Radar (Spider Plot)

# %%
labels = list(grupos.keys())
values = top_startup[labels].values

angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)
values = np.concatenate((values, [values[0]]))
angles = np.concatenate((angles, [angles[0]]))

plt.figure()
ax = plt.axes(polar=True)
ax.plot(angles, values)
ax.fill(angles, values, alpha=0.25)
ax.set_thetagrids(angles[:-1] * 180/np.pi, labels)
plt.title(f"Radar - {top_startup['nome_startup']}")
plt.show()

# %% [markdown]
# # Boxplot por Setor

# %%
plt.figure()
sns.boxplot(data=df_ativas, x='setor', y='Score_Global')
plt.xticks(rotation=45)
plt.title('Distribuição do Score_Global por Setor')
plt.show()

# %% [markdown]
# # Tomada de Decisão (Insight Final)

# %% [markdown]
# Foco: Performance + Viabilidade

# %%
df_ativas['Score_Equilibrio'] = (
    df_ativas['Performance'] + df_ativas['Viabilidade']
) / 2

df_ativas.sort_values('Score_Equilibrio', ascending=False)[
    ['id_startup', 'nome_startup', 'Performance', 'Viabilidade', 'Score_Equilibrio']
].head()
# Out:
#     id_startup   nome_startup  Performance  Viabilidade  Score_Equilibrio
# 27          28      DaletSafe          5.0     4.666667          4.833333
# 41          42     TsadiHydro          5.0     4.333333          4.666667
# 10          11    LambdaCrops          5.0     4.333333          4.666667
# 35          36     LamedDrone          5.0     4.333333          4.666667
# 16          17  RhoIrrigation          5.0     4.333333          4.666667

# %% [markdown]
# **Recomendação:**
# <br>
# A startup com maior Score_Equilibrio apresenta o melhor balanço entre excelência técnica e viabilidade econômica, reduzindo riscos operacionais e financeiros.
